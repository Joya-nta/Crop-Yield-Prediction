# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import joblib

# %%
df = pd.read_csv('../Dataset/WB_Dataset1_with_lon-lat.csv')

# %%
X = df.drop('crop_name', axis=1)
y = df['crop_name']

# %%
df.head()
# Out:
#     latitude  longitude      soil_type  rainfall_mm  season  area_ha  \
# 0  11.061604  89.875740       Laterite          861  Kharif     0.10
# 1   8.874024  70.764010       Laterite         1096  Kharif     1.63
# 2  14.062117  85.383338           Clay          909    Rabi     0.79
# 3  13.921128  90.523077       Alluvial         1377  Kharif     2.83
# 4  28.067624  83.818729  Black (Regur)          786  Kharif     3.13
#
#     crop_name
# 0   Sugarcane
# 1     Millets
# 2      Pulses
# 3  Vegetables
# 4        Jute

# %%
categorical_features = ['soil_type', 'season']
numerical_features = ['rainfall_mm', 'area_ha', 'latitude', 'longitude']
preprocessor = ColumnTransformer(
    transformers=[
        # Convert text to numbers using OneHotEncoder
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
        # Keep numbers as they are
        ('num', 'passthrough', numerical_features)
    ]
)
